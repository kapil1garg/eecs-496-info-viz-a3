# %% [markdown]
# # Load in Libraries and Setup Plotting Environment

# %%
# data loading and manipulation
import os
import requests

import re
import pandas as pd
import numpy as np

# %%
# plotting
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import FuncFormatter
from matplotlib.colors import ListedColormap
# %matplotlib inline

# figure aesthetics
sns.set(font_scale=1.5, style='whitegrid')

# %% [markdown]
# # Load in and Clean Data

# %% [markdown]
# ## Attempt 1: Global Wine Score API

# %%
global_wine_score_path = '../data/global_wine_score.csv'
global_wine_score_df = None

# check if data is saved locally, otherwise use API
if os.path.isfile(global_wine_score_path):
    print('Data loaded from file {}'.format(global_wine_score_path))
    global_wine_score_df = pd.read_csv(global_wine_score_path)
else:
    wine_list_json = []

    api_url = 'https://api.globalwinescore.com/globalwinescores/latest/'
    limit = 10000
    offset = 0
    has_next = True

    while has_next:
        # fetch data from global winescore api
        print('Fetching records {} to {} from {}?limit={}&offset={}'.format(offset, offset + limit, api_url, limit, offset))
        response = requests.get(api_url,
                            params={'limit': limit, 'offset': offset},
                            headers={'Authorization': 'Token {}'.format(os.environ['GLOBAL_WINE_SCORE_API'])})

        # add to existing data list
        if response.status_code == 200: 
            # parse json from response
            response_json = response.json()

            # add data to existing list
            wine_list_json.extend(response_json['results'])

            # check if a next is available
            if response_json['next'] is not None:
                offset += limit
            else:
                has_next = False

    global_wine_score_df = pd.DataFrame.from_dict(wine_list_json, orient='columns')
    global_wine_score_df.to_csv(global_wine_score_path, index=False)

# show loaded dataframe
global_wine_score_df.head()
# Out:
# Data loaded from file ../data/global_wine_score.csv
#               appellation        appellation_slug classification color  \
# 0  Bonnes Mares Grand Cru  bonnes-mares-grand-cru            NaN   Red
# 1             Puente Alto             puente-alto            NaN   Red
# 2              Cote Rotie              cote-rotie            NaN   Red
# 3               Hermitage               hermitage            NaN   Red
# 4               Hermitage               hermitage            NaN   Red
#
#   confidence_index country        date  is_primeurs  journalist_count  \
# 0                A  France  2019-05-31        False                 5
# 1                A   Chile  2019-05-31        False                 3
# 2               B+  France  2019-05-31        False                 4
# 3                A  France  2019-05-31        False                 6
# 4                B  France  2019-05-31        False                 4
#
#         lwin       lwin_11        regions  score  vintage  \
# 0  1056789.0  1.056789e+10  ['Bourgogne']  96.30     2016
# 1  1083246.0  1.083246e+10      ['Chile']  95.63     2016
# 2  1111426.0  1.111426e+10      ['Rhone']  95.45     2016
# 3  1111497.0  1.111497e+10      ['Rhone']  95.15     2016
# 4        NaN           NaN      ['Rhone']  93.14     2015
#
#                                                 wine  wine_id  \
# 0  Domaine Georges & Christophe Roumier, Bonnes M...    58794
# 1                         Vina Almaviva, Puente Alto   140620
# 2              Delas Freres, La Landonne, Cote Rotie    49900
# 3              Delas Freres, Les Bessards, Hermitage    49902
# 4                               E. Guigal, Hermitage    68469
#
#                                            wine_slug wine_type
# 0  domaine-georges-christophe-roumier-bonnes-mare...       NaN
# 1                          vina-almaviva-puente-alto       NaN
# 2                delas-freres-la-landonne-cote-rotie       NaN
# 3                delas-freres-les-bessards-hermitage       NaN
# 4                                 e-guigal-hermitage       NaN

# %% [markdown]
# ## Attempt 2: [Kaggle](https://www.kaggle.com/zynicide/wine-reviews#winemag-data-130k-v2.csv) Wine Review Data

# %%
def extract_vintage(wine_title):
    """
    Extracts vintage of a wine from a given wine title. 
    
    Inputs:
        wine_title (string): title for wine possibly containing vintage
    
    Output: 
        (int or None): year as int or None if title has no year
    """
    vintage_list = re.findall(r'\b\d{4}\b', wine_title)
    
    # check if there is one and only one year, and not a champagne
    if len(vintage_list) == 1 and not ' NV ' in wine_title:
        # check if newer than 1900
        vintage_year = int(vintage_list[0])
        if vintage_year >= 1900: 
            return vintage_year
    return None

# %%
raw_data_path = '../data/'
wine_130k_file = 'winemag-data-130k-v2.csv'

# %%
# convert csv to pandas df
wine_130k_df = pd.read_csv(raw_data_path + wine_130k_file, index_col=0)

# remove unneeded columns for taster
del wine_130k_df['taster_name'], wine_130k_df['taster_twitter_handle']

# add a vintage column
wine_130k_df = wine_130k_df.assign(vintage=wine_130k_df.title.apply(extract_vintage))

# remove any and all NAs
wine_130k_df.dropna(subset=['country', 'points', 'price', 'province', 'title', 'variety', 'winery', 'vintage'], inplace=True) # TODO: specify which cols to drop

# reset index 
wine_130k_df.reset_index(drop=True, inplace=True)
print('Number of records: {}'.format(len(wine_130k_df)))
wine_130k_df.head()
# Out:
# Number of records: 116322
#     country                                        description  \
# 0  Portugal  This is ripe and fruity, a wine that is smooth...
# 1        US  Tart and snappy, the flavors of lime flesh and...
# 2        US  Pineapple rind, lemon pith and orange blossom ...
# 3        US  Much like the regular bottling from 2012, this...
# 4     Spain  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price        province  \
# 0                            Avidagos      87   15.0           Douro
# 1                                 NaN      87   14.0          Oregon
# 2                Reserve Late Harvest      87   13.0        Michigan
# 3  Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 4                        Ars In Vitro      87   15.0  Northern Spain
#
#               region_1           region_2  \
# 0                  NaN                NaN
# 1    Willamette Valley  Willamette Valley
# 2  Lake Michigan Shore                NaN
# 3    Willamette Valley  Willamette Valley
# 4              Navarra                NaN
#
#                                                title             variety  \
# 0      Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 1      Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 2  St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 3  Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 4  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
#
#                 winery  vintage
# 0  Quinta dos Avidagos   2011.0
# 1            Rainstorm   2013.0
# 2           St. Julian   2013.0
# 3         Sweet Cheeks   2012.0
# 4               Tandem   2011.0

# %%
len(wine_130k_df)
# Out:
# 116322

# %%
wine_130k_df.describe()
# Out:
#               points          price        vintage
# count  116322.000000  116322.000000  116322.000000
# mean       88.457024      35.504496    2010.733137
# std         3.046195      41.256275       3.656193
# min        80.000000       4.000000    1934.000000
# 25%        86.000000      17.000000    2009.000000
# 50%        88.000000      25.000000    2011.000000
# 75%        91.000000      42.000000    2013.000000
# max       100.000000    3300.000000    2017.000000

# %%
len(wine_130k_df.region_1.unique())
# Out:
# 1195

# %%
wine_130k_df.country.unique()
# Out:
# array(['Portugal', 'US', 'Spain', 'Italy', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', 'Turkey', 'Czech Republic', 'Slovenia', 'Croatia',
#        'Georgia', 'Uruguay', 'England', 'Lebanon', 'Serbia', 'Brazil',
#        'Moldova', 'Morocco', 'Peru', 'India', 'Bulgaria', 'Cyprus',
#        'Armenia', 'Switzerland', 'Bosnia and Herzegovina', 'Slovakia',
#        'Macedonia', 'Ukraine', 'Luxembourg', 'China'], dtype=object)

# %%
len(wine_130k_df.country.unique())
# Out:
# 42

# %%
with open('../data/wine_titles.txt', 'w') as f:
    for wine_title in list(wine_130k_df.title.unique()):
        f.write("%s\n" % wine_title)

# %%
wine_130k_df.variety.unique()
# Out:
# array(['Portuguese Red', 'Pinot Gris', 'Riesling', 'Pinot Noir',
#        'Tempranillo-Merlot', 'Frappato', 'Gewürztraminer',
#        'Cabernet Sauvignon', 'Chardonnay', 'Malbec', 'Tempranillo Blend',
#        'Meritage', 'Red Blend', 'White Blend', 'Merlot', "Nero d'Avola",
#        'Chenin Blanc', 'Sauvignon Blanc', 'Viognier-Chardonnay',
#        'Primitivo', 'Catarratto', 'Gamay', 'Inzolia', 'Petit Verdot',
#        'Monica', 'Bordeaux-style White Blend', 'Grillo', 'Sangiovese',
#        'Cabernet Franc', 'Bordeaux-style Red Blend', 'Aglianico',
#        'Petite Sirah', 'Carmenère', 'Albariño', 'Petit Manseng', 'Rosé',
#        'Zinfandel', 'Vernaccia', 'Rosato', 'Grüner Veltliner', 'Viognier',
#        'Vermentino', 'Grenache Blanc', 'Syrah', 'Nebbiolo',
#        'Shiraz-Cabernet Sauvignon', 'Pinot Blanc', 'Alsace white blend',
#        'Barbera', 'Rhône-style Red Blend', 'Portuguese White', 'Graciano',
#        'Tannat-Cabernet', 'Sauvignon', 'Torrontés', 'Prugnolo Gentile',
#        'G-S-M', 'Verdejo', 'Fumé Blanc', 'Furmint', 'Pinot Bianco',
#        'Bonarda', 'Shiraz', 'Montepulciano', 'Grenache',
#        'Ugni Blanc-Colombard', 'Syrah-Viognier', 'Blaufränkisch',
#        'Friulano', 'Assyrtico', 'Carignan-Grenache', 'Savagnin',
#        'Cabernet Sauvignon-Syrah', 'Prosecco', 'Vignoles',
#        'Shiraz-Viognier', 'Garganega', 'Pinot Grigio', 'Tempranillo',
#        'Sparkling Blend', 'Cortese', 'Mencía', 'Zweigelt',
#        'Nerello Mascalese', 'Melon', 'Rhône-style White Blend', 'Vidal',
#        'Champagne Blend', 'Cannonau', 'Verdelho', 'Marsanne', 'Scheurebe',
#        'Kerner', 'Syrah-Grenache', 'Dolcetto', 'Vilana', 'Glera', 'Viura',
#        'Garnacha Tintorera', 'Pinot Nero', 'Pinotage', 'Sémillon',
#        'Pinot Noir-Gamay', 'Antão Vaz', 'Cabernet Sauvignon-Carmenère',
#        'Verdejo-Viura', 'Verduzzo', 'Verdicchio', 'Silvaner', 'Colombard',
#        'Carricante', 'Sylvaner', 'Fiano', 'Früburgunder', 'Sousão',
#        'Roussanne', 'Avesso', 'Cinsault', 'Tinta Miúda',
#        'Muscat Blanc à Petits Grains', 'Monastrell', 'Xarel-lo',
#        'Trebbiano', 'Corvina, Rondinella, Molinara',
#        'Chenin Blanc-Chardonnay', 'Insolia', 'Merlot-Malbec',
#        'Ribolla Gialla', 'Cabernet Sauvignon-Merlot', 'Port',
#        'Weissburgunder', 'Roditis', 'Traminer', 'Papaskarasi',
#        'Tannat-Syrah', 'Marsanne-Roussanne', 'Charbono',
#        'Sangiovese Grosso', 'Merlot-Argaman', 'Greco', 'Prié Blanc',
#        'Provence red blend', 'Zibibbo', 'Falanghina', 'Garnacha',
#        'Negroamaro', 'Mourvèdre', 'Syrah-Cabernet', 'Müller-Thurgau',
#        'Pinot Meunier', 'Cabernet Sauvignon-Sangiovese',
#        'Austrian Red Blend', 'Teroldego', 'Sagrantino', 'Tannat',
#        'Pansa Blanca', 'Muskat Ottonel', 'Sauvignon Blanc-Semillon',
#        'Claret', 'Semillon-Sauvignon Blanc', 'Bical', 'Touriga Nacional',
#        'Moscatel', 'Rosado', 'Viura-Chardonnay', 'Baga',
#        'Malvasia Bianca', 'Gelber Muskateller', 'Malbec-Merlot',
#        'Monastrell-Syrah', 'Malbec-Tannat', 'Malbec-Cabernet Franc',
#        'Moscato', 'Refosco', 'Turbiana', 'Alvarinho', 'Agiorgitiko',
#        'Muscat', 'Malagousia', 'Assyrtiko', 'Ruché', 'Welschriesling',
#        'Tinta de Toro', 'Rieslaner', 'Traminette', 'Chambourcin',
#        'Lambrusco di Sorbara', 'Cesanese', 'Feteasca Neagra', 'Lagrein',
#        'Tinta Fina', 'St. Laurent', 'Marsanne-Viognier',
#        'Cabernet Sauvignon-Shiraz', 'Syrah-Cabernet Sauvignon',
#        'Gewürztraminer-Riesling', 'Pugnitello', 'Cerceal',
#        'Touriga Nacional Blend', 'Tocai', 'Fernão Pires',
#        'Cabernet Franc-Cabernet Sauvignon', 'Grenache-Syrah',
#        'Seyval Blanc', 'Muscat Canelli', 'Cabernet Merlot',
#        'Tempranillo-Cabernet Sauvignon', 'Arinto',
#        'Merlot-Cabernet Franc', 'Syrah-Petite Sirah', 'Cabernet Blend',
#        'Maturana', 'Pecorino', 'Rotgipfler', 'Kinali Yapincak',
#        'Cabernet Franc-Carmenère', 'Gamay Noir', 'Sauvignon Gris',
#        'Spätburgunder', 'Picpoul', 'Albanello', 'Arneis', 'Malvasia',
#        'Plavac Mali', 'Lemberger', 'Saperavi', 'Altesse', 'Blanc du Bois',
#        'Provence white blend', 'Nosiola', 'Dornfelder',
#        'Roussanne-Viognier', 'Godello', 'Mondeuse', 'Perricone',
#        'Auxerrois', 'Syrah-Merlot', 'Albana', 'Muskat',
#        'Cabernet Sauvignon-Malbec', 'Tinto Fino',
#        'Malbec-Cabernet Sauvignon', 'Moschofilero', 'Grechetto',
#        'Encruzado', 'Carignano', 'Cabernet Franc-Merlot', 'Torbato',
#        'Syrah-Petit Verdot', 'Garnacha Blanca', 'Pallagrello', 'Morava',
#        'Syrah-Mourvèdre', 'Aleatico', 'Kisi', 'Zierfandler',
#        'Vidal Blanc', 'Shiraz-Grenache', 'Magliocco', 'Grenache-Carignan',
#        'Nascetta', 'Portuguese Sparkling', 'Siria', 'Malbec-Syrah',
#        'Feteascǎ Regalǎ', 'Marselan', 'Tocai Friulano', 'Schiava',
#        'Alfrocheiro', 'Chardonnay-Semillon', 'Norton',
#        'Alicante Bouschet', 'Tokaji', 'Moscadello',
#        'Cabernet Sauvignon-Tempranillo', 'Carignan', 'Loureiro-Arinto',
#        'Lambrusco Grasparossa', 'Cabernet-Syrah',
#        'Sauvignon Blanc-Chardonnay', 'Symphony', 'Edelzwicker',
#        'Black Muscat', 'Grenache Noir', 'Durella', 'Xinomavro',
#        'Tinto del Pais', 'Merlot-Cabernet Sauvignon', 'Cercial',
#        'Roter Veltliner', 'Johannisberg Riesling', 'Petite Verdot',
#        'Passerina', 'Valdiguié', 'Colombard-Sauvignon Blanc', 'Kangoun',
#        'Loureiro', 'Posip', 'Uva di Troia', 'Gros and Petit Manseng',
#        'Jacquère', 'Kalecik Karasi', 'Karasakiz', 'Mourvèdre-Syrah',
#        'Negrette', 'Zierfandler-Rotgipfler', 'Clairette', 'Aragonez',
#        'País', 'Chardonnay-Viognier', 'Mauzac', 'Pinot Auxerrois',
#        'Chenin Blanc-Sauvignon Blanc', 'Diamond', 'Marzemino',
#        'Tinta Barroca', 'Chardonnay-Sauvignon Blanc', 'Castelão',
#        'Trebbiano Spoletino', 'Teran', 'Trepat', 'Freisa',
#        'Nero di Troia', 'Chasselas', 'Tinta Roriz', 'Hárslevelü',
#        'Trincadeira', 'Merlot-Tannat', 'Rkatsiteli', 'Siegerrebe',
#        'Trousseau Gris', 'Grenache Blend', 'Austrian white blend',
#        'Muscadelle', 'Gros Manseng', 'Portuguese Rosé', 'Lambrusco',
#        'Brachetto', 'Muskateller', 'Aligoté', 'Sangiovese Cabernet',
#        'Touriga Nacional-Cabernet Sauvignon', 'Muscat Blanc', 'Argaman',
#        'Viognier-Roussanne', 'Pallagrello Bianco', 'Bobal',
#        'Malvasia Istriana', 'Cabernet Sauvignon-Cabernet Franc',
#        'Baco Noir', 'Veltliner', 'Tempranillo-Tannat', 'Morillon',
#        'Touriga Franca', 'Barbera-Nebbiolo', 'Prieto Picudo', 'Gaglioppo',
#        'Piedirosso', 'Piquepoul Blanc', 'Chardonnay-Sauvignon',
#        'Tempranillo-Garnacha', 'Carmenère-Cabernet Sauvignon',
#        'Chenin Blanc-Viognier', 'Susumaniello', 'Vitovska',
#        'Orange Muscat', 'Grauburgunder', 'Carignane', 'Moscatel Roxo',
#        'Picolit', 'Nerello Cappuccio', 'Counoise', 'Macabeo', 'Mazuelo',
#        'Sauvignon-Sémillon', 'Tinta del Pais', 'Vranec', 'Corvina',
#        'Mavrud', "Cesanese d'Affile", 'Moscato Giallo', 'Verdil',
#        'Cabernet', 'Verduzzo Friulano ', 'Treixadura', 'Duras',
#        "Loin de l'Oeil", 'Coda di Volpe', 'Grenache-Mourvèdre',
#        'Forcallà', 'Viura-Verdejo', 'Manzoni', 'Pinot-Chardonnay',
#        'Syrah-Tempranillo', 'Cabernet Sauvignon-Barbera',
#        'Merlot-Cabernet', "Muscat d'Alexandrie", 'Jaen', 'Tinta del Toro',
#        'Timorasso', 'Pigato', 'Sangiovese-Cabernet Sauvignon',
#        'Shiraz-Cabernet', 'Viognier-Gewürztraminer', 'Prunelard',
#        'Sauvignon Blanc-Chenin Blanc', 'Gros Plant',
#        'Malbec-Petit Verdot', 'Colombard-Ugni Blanc', 'Sacy', 'Mansois',
#        'Grignolino', 'Garnacha-Syrah', 'Rufete', 'Pedro Ximénez',
#        'Tempranillo-Shiraz', 'Mtsvane', 'Chardonnay-Pinot Gris', 'Marawi',
#        'Chardonnay-Pinot Blanc', 'Mataro', 'Tinta Cao',
#        'Blauer Portugieser', 'Ugni Blanc', 'Groppello',
#        'Semillon-Chardonnay', 'Irsai Oliver', 'Raboso', 'Alvarelhão',
#        'Poulsard', 'Grenache-Shiraz', 'Baga-Touriga Nacional', 'Carineña',
#        'Pignoletto', 'Muscatel', 'Ciliegiolo', 'Mantonico',
#        'Viognier-Grenache Blanc', 'Cabernet Sauvignon-Merlot-Shiraz',
#        'Alicante', 'Emir', 'Narince', 'Malbec-Cabernet', 'Touriga',
#        'Grecanico', 'Carmenère-Syrah', 'Madeleine Angevine', 'Neuburger',
#        'Mavroudi', 'Pinot Blanc-Pinot Noir', 'Muscat Hamburg',
#        'Tempranillo Blanco', 'Aragonês', 'Casavecchia',
#        'Pinot Gris-Gewürztraminer', 'White Riesling', 'Tinto Velasco',
#        'Hondarrabi Zuri', 'Nuragus', 'Xynisteri', 'Kadarka',
#        'Sauvignon Musqué', 'Roussanne-Marsanne', 'Incrocio Manzoni',
#        'Terrantez', 'Bual', 'Okuzgozu', 'Rivaner', 'Doña Blanca',
#        'Graševina', 'Sangiovese-Syrah', 'Tannat-Cabernet Franc',
#        'Thrapsathiri', 'Fer Servadou', 'Mission', 'Kekfrankos',
#        'Cococciola', 'Lambrusco Salamino', 'Blauburgunder',
#        'Tannat-Merlot', 'Marquette', 'Romorantin', 'Bombino Bianco',
#        'Verdejo-Sauvignon Blanc', 'Braucol', 'Malvasia-Viura',
#        'Cabernet Franc-Malbec', 'Pallagrello Nero', 'Rebula', 'Vespolina',
#        'Shiraz-Malbec', 'Rebo', 'Tamjanika', 'Chinuri', 'Trousseau',
#        'Syrah-Malbec', 'Syrah-Cabernet Franc', 'Macabeo-Moscatel',
#        'Cariñena-Garnacha', 'Plyto', 'Códega do Larinho', 'Sideritis',
#        'Çalkarası', 'Azal', 'Moscatel Graúdo', 'Viosinho',
#        'Moschofilero-Chardonnay', 'Paralleda', 'Malvasia di Candia',
#        'Maria Gomes', 'Malvar', 'Airen', 'Erbaluce',
#        'Muscat of Alexandria', 'Verdosilla', 'Abouriou',
#        'Pinot Noir-Syrah', 'Nielluciu', 'Malbec-Bonarda', 'Vespaiolo',
#        'Malbec-Carménère', 'Biancolella', 'Sauvignon Blanc-Verdejo',
#        'Aidani', 'Garnacha-Monastrell', 'Greco Bianco', 'Vinhão',
#        'Souzao', 'Roter Traminer', 'Moscatel de Alejandría', 'Rolle',
#        'Tinta Francisca', 'Malvasia Nera', 'Orangetraube',
#        'Riesling-Chardonnay', 'Žilavka', 'Portuguiser', 'Listán Negro',
#        'Pinotage-Merlot', 'Muscadine', 'Maria Gomes-Bical', 'Grolleau',
#        'Zlahtina', 'Syrah-Grenache-Viognier', 'Jacquez', 'Gouveio',
#        'Canaiolo', 'Carignan-Syrah', 'Bombino Nero',
#        'Chardonnay-Riesling', 'Malagouzia-Chardonnay', 'Mavrotragano',
#        'Bovale', 'Frankovka', 'Shiraz-Roussanne', 'Cabernet-Shiraz',
#        'Syrah-Carignan', 'Elbling', 'Gragnano', 'Mavrodaphne',
#        'Garnacha Blend', 'Savatiano', 'Schwartzriesling', 'Bastardo',
#        'Vidadillo', 'Misket', 'Chardonnay Weissburgunder',
#        'Macabeo-Chardonnay', 'Robola', 'Merlot-Shiraz', 'Malagouzia',
#        'Sämling', 'Folle Blanche', 'Malbec Blend', 'Merlot-Syrah',
#        'Tamianka', 'Cabernet Pfeffer', 'Morio Muskat', 'Rabigato',
#        'Babić', 'Yapincak', 'Sauvignonasse', 'Viognier-Marsanne',
#        'Meseguera', 'Alvarinho-Chardonnay', 'Saperavi-Merlot',
#        'Pinot Blanc-Viognier', 'Teroldego Rotaliano',
#        'Garnacha-Tempranillo', 'Xinisteri', 'Trebbiano di Lugana',
#        'Albarossa', 'Ryzlink Rýnský', 'Verdeca',
#        'Cabernet Sauvignon Grenache', 'Tămâioasă Românească', 'Sherry',
#        'Merlot-Grenache', 'Tempranillo-Syrah', 'Chardonel',
#        'Silvaner-Traminer', 'Uvalino', 'Merseguera-Sauvignon Blanc',
#        'Cabernet-Malbec', 'Boğazkere', 'Gelber Traminer',
#        'Vermentino Nero', 'Cayuga', 'Tinta Amarela', 'Rara Neagra',
#        'Tinta Negra Mole', 'Moscato Rosa', 'Chelois',
#        'Sauvignon Blanc-Assyrtiko', 'Muscadel', 'Shiraz-Tempranillo',
#        'Roussanne-Grenache Blanc', 'Biancale', 'Ansonica',
#        'Syrah-Bonarda', 'Durif', 'Roviello', 'Franconia',
#        'Malbec-Tempranillo', 'Nasco', 'Monastrell-Petit Verdot', 'Sirica',
#        'Pinot Grigio-Sauvignon Blanc', 'Blatina', 'Karalahna', 'Feteasca',
#        'Sercial', 'Valvin Muscat', 'Malvasia Fina',
#        'Roditis-Moschofilero', 'St. Vincent', 'Chancellor', 'Premsal',
#        'Jampal', 'Tokay Pinot Gris', 'Colorino', 'Picapoll', 'Blauburger',
#        'Tinta Madeira', 'Centesimino', 'Grenache Gris', 'Trajadura',
#        'Merlot-Petite Verdot', 'Cabernet Moravia', 'Ramisco',
#        'Catalanesca', 'Garnacha-Cabernet', 'Garnacha-Cariñena', 'Gamza',
#        'Cabernet Franc-Lemberger', 'Pinot Blanc-Chardonnay',
#        'Chardonnay-Albariño', 'Shiraz-Mourvèdre', 'Mavrokalavryta',
#        'Favorita', 'Babosa Negro', 'Tintilia ', 'Dafni', 'Sciaccerellu',
#        'Petit Courbu', 'Kotsifali', 'Parraleta', 'Moscato di Noto',
#        'Torontel', 'Viognier-Valdiguié', 'Trollinger', 'Mandilaria',
#        'Francisa', 'Kuntra', 'Debit', 'Pignolo', 'Asprinio', 'Caprettone',
#        'Ondenc', 'Athiri', 'Bobal-Cabernet Sauvignon'], dtype=object)

# %%
len(wine_130k_df.variety.unique())
# Out:
# 681
